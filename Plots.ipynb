# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from pickle import load

# %%
with open('results/mnist_mle_evals.pkl', 'r') as f:
    mnist_mle_evals = load(f)
    
with open('results/mnist_mm_evals.pkl', 'r') as f:
    mnist_mm_evals = load(f)
    
with open('results/reacher_mle_evals.pkl', 'r') as f:
    reacher_mle_evals = load(f)
    
with open('results/reacher_mm_evals.pkl', 'r') as f:
    reacher_mm_evals = load(f)

# %%
plt.figure(figsize=(10, 8))
plt.plot(mnist_mle_evals['ts'], [x['accu'] for x in mnist_mle_evals['tr']], '--', label='MLE Train', c='blue')
plt.plot(mnist_mle_evals['ts'], [x['accu'] for x in mnist_mle_evals['t']], '-', label='MLE Test', c='blue')

plt.plot(mnist_mle_evals['ts'], [x['accu'] for x in mnist_mm_evals['tr']], '--', label='MM Train', c='green')
plt.plot(mnist_mle_evals['ts'], [x['accu'] for x in mnist_mm_evals['t']], '-', label='MM Test', c='green')
plt.legend(fontsize=fs)
plt.title('MNIST Accuracy MLE vs MM', fontsize=20)
plt.ylabel('Accuracy', fontsize=18)
plt.xlabel('Batches', fontsize=18)
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(mnist_mle_evals['ts'], [x['loss'] for x in mnist_mle_evals['tr']], '--', label='MLE Train', c='blue')
plt.plot(mnist_mle_evals['ts'], [x['loss'] for x in mnist_mle_evals['t']], '-', label='MLE Test', c='blue')

plt.plot(mnist_mle_evals['ts'], [x['loss'] for x in mnist_mm_evals['tr']], '--', label='MM Train', c='green')
plt.plot(mnist_mle_evals['ts'], [x['loss'] for x in mnist_mm_evals['t']], '-', label='MM Test', c='green')
plt.legend(fontsize=fs)
plt.title('MNIST Loss MLE vs MM', fontsize=20)
plt.ylabel('Loss', fontsize=18)
plt.xlabel('Batches', fontsize=18)
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(reacher_mle_evals['ts'], reacher_mle_evals['tr_loss'], '--', label='MLE Train', c='blue')
plt.plot(reacher_mm_evals['ts'], reacher_mm_evals['tr_loss'], '--', label='MM Train', c='green')
plt.legend(fontsize=fs)
plt.title('Reacher Loss MLE vs MM', fontsize=20)
plt.ylabel('Loss', fontsize=18)
plt.xlabel('Batches', fontsize=18)
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(reacher_mle_evals['ts'], reacher_mle_evals['mean_r'], label='MLE', c='blue')
plt.plot(reacher_mm_evals['ts'], reacher_mm_evals['mean_r'], label='MM', c='green')
plt.legend(fontsize=fs)
plt.title('Reacher Rewards MLE vs MM', fontsize=20)
plt.ylabel('Reward', fontsize=18)
plt.xlabel('Batches', fontsize=18)
plt.show()
